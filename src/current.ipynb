# %%
from __future__ import division
from __future__ import print_function

import sys
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
from DL import DataLoader, Batch
import decode_beam
import tensorflow as tf
from SamplePreprocessor import preprocess
import os
import pathlib
import BestPath
import Common
import time
import copy
import math

# %%
class DecoderType:
    BestPath = 0
    BeamSearch = 1
    WordBeamSearch = 2

# %%
class FilePaths:
    "filenames and paths to data"
    fnCharList = (r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\model\charList.txt')
    fnAccuracy = (r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\model\accuracy.txt')
    #c = (r'C:\Users')
    #fnTrain = os.path.join(c, "User", "fastai", "courses", "dl1","Handwriting recognition project","data")
    #fnTrain = (r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\data')
    fnTrain = pathlib.Path(r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\data')
    #print (fnTrain)
    fnInfer = (r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\data\test.png')
    fnCorpus = (r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\data\corpus.txt')

# %%
class Model(torch.nn.Module): 
        
    # model constants
    batchSize = 50
    imgSize = (128, 32)
    maxTextLen = 32
    
    def __init__(self):
        super(Model, self).__init__()
        self.snapID = 0
        #self.is_train = tf.placeholder(tf.bool, name='is_train')
        
        # input image batch
        #self.inputImgs = tf.placeholder(tf.float32, shape=(None, Model.imgSize[0], Model.imgSize[1]))
        #self.inputImgs = torch.tensor(batch.imgs, Model.imgSize[0], Model.imgSize[1])
        
        #cnn function
        self.conv1 = torch.nn.Conv2d(1, 32, 5, stride = 1, padding = 2).cuda()
        self.batchnorm1 = torch.nn.BatchNorm2d(32).cuda().cuda()
        self.relu1 = torch.nn.ReLU().cuda()
        self.pool1 = torch.nn.MaxPool2d((2,2), stride = (2,2)).cuda()
        
        self.conv2 = torch.nn.Conv2d(32, 64, 5, stride = 1, padding = 2).cuda()
        self.batchnorm2 = torch.nn.BatchNorm2d(64).cuda()
        self.relu2 = torch.nn.ReLU().cuda()
        self.pool2 = torch.nn.MaxPool2d((2,2), stride = (2,2)).cuda()
        
        self.conv3 = torch.nn.Conv2d(64, 128, 3, stride = 1, padding = 1).cuda()
        self.batchnorm3 = torch.nn.BatchNorm2d(128).cuda()
        self.relu3 = torch.nn.ReLU().cuda()
        self.pool3 = torch.nn.MaxPool2d((1,2), stride = (1,2)).cuda()  
        
        self.conv4 = torch.nn.Conv2d(128, 128, 3, stride = 1, padding = 1).cuda()
        self.batchnorm4 = torch.nn.BatchNorm2d(128).cuda()
        self.relu4 = torch.nn.ReLU().cuda()
        self.pool4 = torch.nn.MaxPool2d((1,2), stride = (1,2)).cuda()
        
        self.conv5 = torch.nn.Conv2d(128, 256, 3, stride = 1, padding = 1).cuda()
        self.batchnorm5 = torch.nn.BatchNorm2d(256).cuda()
        self.relu5 = torch.nn.ReLU().cuda()
        self.pool5 = torch.nn.MaxPool2d((1,2), stride = (1,2)).cuda()
        
        #rnn function
        self.lstm = torch.nn.LSTM(256, 256, 2, batch_first = True, bidirectional = True).cuda()
        # BxTxH + BxTxH -> BxTx2H -> BxTx1x2H 
        #squeeze
        self.rnnconv2d = torch.nn.Conv2d(512, 80, 1, stride = 1, padding = 0).cuda()
        
    def forward(self, inputImgs):
        #cnn forward pass
        inputTensor = torch.from_numpy(inputImgs).cuda()
        inputTensor = inputTensor.type(torch.FloatTensor).cuda()
        inputTensor = torch.unsqueeze(inputTensor, 1)
        #print (inputTensor.size()) [50,1,128,32]
        out = self.conv1(inputTensor)
        out = self.batchnorm1(out)
        out = self.relu1(out)
        out = self.pool1(out)
        out = self.conv2(out)
        out = self.batchnorm2(out)
        out = self.relu2(out)
        out = self.pool2(out)
        out = self.conv3(out)
        out = self.batchnorm3(out)
        out = self.relu3(out)
        out = self.pool3(out)
        out = self.conv4(out)
        out = self.batchnorm4(out)
        out = self.relu4(out)
        out = self.pool4(out)
        out = self.conv5(out)
        out = self.batchnorm5(out)
        out = self.relu5(out)
        out = self.pool5(out)
        
        #rnn forward pass
        #print (cnn.size())
        out = torch.squeeze(out, 3)
        out = out.permute(0,2,1)
        #print (cnn.size()) cnn= [50,32,256]
        #h0, c0 shape (num_layers * num_directions, batch, hidden_size):
        h0 = torch.zeros(4, out.size(0), 256).cuda()
        c0 = torch.zeros(4, out.size(0), 256).cuda()
        #packed_cnn = torch.nn.utils.rnn.pack_padded_sequence(cnn, [32]*cnn.size(1))
        #print(packed_cnn.size())
        out, _ = self.lstm(out, (h0,c0))
        #print (rnn_out.size())
        #rnn_out, _ = torch.nn.utils.rnn.pad_packed_sequence(rnn_out, batch_first=False)
        #print (rnn_out.size()) [50,32,512]
        out = torch.unsqueeze(out, 3) #[50,512,32,1]
        out = out.permute(0,2,1,3) #[50,32,1,512]
        #print (rnn_out.size())
        #print (rnn_out.size())
        out = self.rnnconv2d(out)
        #out = self.fnl(rnn_out)
        return out

# %%
#literally just copy this function
def toSparse(texts):
    "put ground truth texts into sparse tensor for ctc_loss"
    indices = []
    values = []
    shape = [len(texts), 0] # last entry must be max(labelList[i])
    charList = open(FilePaths.fnCharList).read()
    # go over all texts
    for (batchElement, text) in enumerate(texts):
        # convert to string of label (i.e. class-ids)
        labelStr = [charList.index(c) for c in text]
        # sparse tensor must have size of max. label-string
        if len(labelStr) > shape[1]:
            shape[1] = len(labelStr)
        # put each label into sparse tensor
        for (i, label) in enumerate(labelStr):
            indices.append([batchElement, i])
            values.append(label)

    return (indices, values, shape)

# %%
def fromSparse(indices, values, shape):
    "put ground truth texts into sparse tensor for ctc_loss"
    outputMatrix = torch.zeros(shape[0], shape[1], dtype = torch.long).cuda()
    numValues = len(values)
    targetLen = [0]*shape[0]
    index = 0
    for i in range(numValues):
        if indices[i][0] != 0 and indices[i][0] != indices[i-1][0]:
            index +=1
        dim0 = indices[i][0]
        dim1 = indices[i][1]
        outputMatrix[dim0, dim1]= values[i]
        targetLen[index]+=1
    return outputMatrix, targetLen

# %%
def recLabelingProb(t, s, mat, labelingWithBlanks, blank, cache):
	"recursively compute probability of labeling, save results of sub-problems in cache to avoid recalculating them"

	# check index of labeling
	if s < 0:
		return 0.0

	# sub-problem already computed
	if cache[t][s] != None:
		return cache[t][s]

	# initial values
	if t == 0:
		if s == 0:
			res = mat[0, blank]
		elif s == 1:
			res = mat[0, labelingWithBlanks[1]]
		else:
			res = 0.0

		cache[t][s] = res
		return res

	# recursion on s and t
	res = (recLabelingProb(t-1, s, mat, labelingWithBlanks, blank, cache) + recLabelingProb(t-1, s-1, mat, labelingWithBlanks, blank, cache)) * mat[t, labelingWithBlanks[s]]

	# in case of a blank or a repeated label, we only consider s and s-1 at t-1, so we're done
	if labelingWithBlanks[s] == blank or (s >= 2 and labelingWithBlanks[s-2] == labelingWithBlanks[s]):
		cache[t][s] = res
		return res

	# otherwise, in case of a non-blank and non-repeated label, we additionally add s-2 at t-1
	res += recLabelingProb(t-1, s-2, mat, labelingWithBlanks, blank, cache) * mat[t, labelingWithBlanks[s]]
	cache[t][s] = res
	return res

# %%
def emptyCache(maxT, labelingWithBlanks):
	"create empty cache"
	return [[None for _ in range(len(labelingWithBlanks))] for _ in range(maxT)]

# %%
def ctcLabelingProb(mat, gt, classes):
	"calculate probability p(gt|mat) of a given labeling gt and a matrix mat according to section 'The CTC Forward-Backward Algorithm' in Graves paper"
	maxT, _ = mat.shape # size of input matrix
	blank = len(classes) # index of blank label
	labelingWithBlanks = Common.extendByBlanks(Common.wordToLabelSeq(gt, classes), blank) # ground truth text as label string extended by blanks
	cache = emptyCache(maxT, labelingWithBlanks) # cache subresults to avoid recalculating  subproblems over and over again
	return recLabelingProb(maxT-1, len(labelingWithBlanks)-1, mat, labelingWithBlanks, blank, cache) + recLabelingProb(maxT-1, len(labelingWithBlanks)-2, mat, labelingWithBlanks, blank, cache)

# %%
def softmax(mat):
    "calc softmax such that labels per time-step form probability distribution"
    maxT, _ = mat.shape # dim0=t, dim1=c
    res = np.zeros(mat.shape)
    for t in range(maxT):
        y = mat[t, :]
        e = np.exp(y)
        s = np.sum(e)
        if math.isinf(s):
            res[t, :] = 0
        else:
            res[t, :] = e/s
    return res

# %%
def printStats(phase, loss, acc, prob, best_prob):
    string = "{} Loss: {:.4f} Epoch Acc: {:.2E} Epoch Prob: {:.2E} Best Probability: {:.2E}".format(phase, loss, acc, prob, best_prob)
    return string

# %%
def printEpoch(epoch, num_epoch, start):
    string = "Epoch {}/{} : {} - {:.0f}h {:.0f}m\n{}\n".format(epoch, num_epoch, time.asctime(),
                                                             (time.time() - start)//3600, ((time.time() - start)//60)%60, '-' * 10)
    return string

# %%
def getdata(phase):
    loader = DataLoader(filePath = FilePaths.fnTrain, batchSize = Model.batchSize, imgSize = Model.imgSize, maxTextLen = Model.maxTextLen)
    if phase == 'train':
        loader.trainSet()
    else:
        loader.validationSet()
    batch, labels, wlabels = [], [], []
    batchNumber = 0
    while loader.hasNext():
#        iterInfo = loader.getIteratorInfo()
        batch.append(loader.getNext())
        labels.append(toSparse(batch[batchNumber].gtTexts))
        wlabels.append(batch[batchNumber].gtTexts)
        numBatchElements = len(batch[batchNumber].imgs)
#        seqLen.append(Model.maxTextLen * numBatchElements)
        batchNumber+= 1
    numberOfBatches = batchNumber
    charList = loader.charList
    return batch, labels, wlabels, numberOfBatches, charList

# %%
def train_model(model, num_epochs=25, learning_rate = 0.01, decoderType=DecoderType.BestPath):
    since = time.time()
    ctcloss, optimizer = createLossAndOptimizer(model, learning_rate)
    # prepare information about language (dictionary, characters in dataset, characters forming words)    
    wordChars = open(r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\model\charList.txt').read().splitlines()[0]
    corpus = open(r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\data\corpus.txt').read()
    PATH = (r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\model\checkpoint.pt')
    #get input and labels
    batchtrain, labelstrain, wlabelstrain, numberOfBatchestrain, charList = getdata('train')
    batchval, labelsval, wlabelsval, numberOfBatchesval, charList = getdata('val')
    chars = str().join(charList)
    best_prob = 0.0
    # Loading checkpoint
    if os.path.exists(PATH):
        print("Checkpoint loaded")
        checkpoint = torch.load(PATH)
        model.state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        current_epoch = checkpoint['epoch'] + 1
        best_prob = checkpoint['best_prob']
        best_model_wts = checkpoint['best_wts']
    else:
        best_prob = 0.0
        current_epoch = 0
        best_model_wts = copy.deepcopy(model.state_dict())
        
    for epoch in range(current_epoch, num_epochs):
        if epoch < 100:
            learning_rate = 0.01
        elif epoch < 10000: 
            learning_rate = 0.001
        else:
            learning_rate = 0.0001
            
        print(printEpoch(epoch, num_epochs - 1, since))
        #compute output and loss
        for phase in ['train','val']:
            if phase == 'train':
                model.train()
                batch, labels, wlabels, numberOfBatches, charList = batchtrain, labelstrain, wlabelstrain, numberOfBatchestrain, charList
            else:
                model.eval()
                batch, labels, wlabels, numberOfBatches, charList = batchval, labelsval, wlabelsval, numberOfBatchesval, charList
            
            running_loss = 0.0
            running_accuracy = 0.0
            running_probability = 0.0
            # zero the parameter gradients    
            model.zero_grad()
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(phase == 'train'):
                torch.autograd.set_detect_anomaly(True)
                for batchNumber in range(numberOfBatches):
                    optimizer.zero_grad()
                    #print (batch[batchNumber].imgs.shape)
                    out= model(batch[batchNumber].imgs)
                    #print (out.size())
                    out = out.squeeze(3)
                    out = out.permute(2,0,1)
                    #out size [32,50,80]
                    
                    #print (out)
                    #print (type(out))
                    #print (out.size())
                    #print (len(wlabels[batchNumber]))
                    #print (wlabels[batchNumber])
                    #labels[batchNumber] include indices, values (based on charlist.txt), shapes(batchsize, maxtextlength in batch)
                    #print (len(labels[batchNumber]))
                    #print (labels[batchNumber])
                    targets, targetsLen = fromSparse(labels[batchNumber][0], labels[batchNumber][1], labels[batchNumber][2])
                    #targets is a matrix [batchsize, maxtextlength] with value in index correspond with charList
                    #print (type(targets[0,0]))
                    #print (targets[0,0])
                    #inputsLen = tuple([32] * labels[batchNumber][2][0])
                    inputsLen = torch.full(size=(50,), fill_value=32, dtype=torch.long).cuda()
                    targetsLen = torch.LongTensor(targetsLen).cuda()
                    #print (targets)
                    #print (targetsLen)
                    # calc loss for batch
                    
                    logProbs = torch.nn.functional.log_softmax(out, dim = 2).requires_grad_().cuda()
                    #print (logProbs)
                    loss = torch.mean(ctcloss(logProbs, targets, inputsLen,targetsLen)).requires_grad_().cuda()
                    #loss = ctcloss(logProbs, targets, inputsLen,targetsLen).requires_grad_().cuda()
                    #print (logProbs)
                    
                    #out2 = out.permute(1,0,2)
                    out2 = out.permute(1,0,2)
                    #print(out2.is_cuda)
                    #out2 = out2.cpu().detach().numpy()
                    outputText = []
                    accurateWords = 0
                    prob = []
                    #print(loss.is_cuda)
                    
                    for i in range (out2.shape[0]):
                        #print (wlabels[batchNumber][i])
                        #print (prob[i])
                        #decode output to Text
                        #print (softmaxOut)
                        softmaxOut = torch.nn.functional.softmax(out2[i], dim = 1).cuda()
                        softmaxOut = softmaxOut.cpu().detach().numpy()
                        #print (softmaxOut)
                        outputText.append(BestPath.ctcBestPath(softmaxOut, charList))
                        #calculate confidence of each words
                        prob.append(ctcLabelingProb(softmaxOut, wlabels[batchNumber][i],charList))
                        #print (prob[i])
                        #if math.isnan(prob[i]):
                            #print (prob[i])
                            #print (wlabels[batchNumber][i])                            
                            #print (batchNumber)
                            #print (i)
                        if outputText[i] == wlabels[batchNumber][i]:
                            accurateWords +=1
                    batchAccuracy = accurateWords/len(outputText)
                    #print (wlabels[batchNumber])
                    batchProb = sum(prob)/len(prob)
                    #print (outputText)
                    #print (batchProb)
#                    print (len(outputText))
#                     tfOut = out.detach().numpy()
#                     print (tfOut)
#                     print (type(tfOut))
#                     sess = tf.Session()
#                     with sess.as_default():
#                         tfOut = tf.constant(tfOut, dtype = tf.float32)
#                     print (tfOut)
#                     print (type(tfOut))
#                     # decoder: either best path decoding or beam search decoding
#                     if decoderType == DecoderType.BestPath:
#                         decoder = tf.nn.ctc_greedy_decoder(inputs=tfOut, sequence_length=seqLen[batchNumber])
#                     elif decoderType == DecoderType.BeamSearch:
#                         decoder = tf.nn.ctc_beam_search_decoder(inputs=out, sequence_length=seqLen[batchNumber], beam_width=50, merge_repeated=False)
#                     elif self.decoderType == DecoderType.WordBeamSearch:
#                         # import compiled word beam search operation (see https://github.com/githubharald/CTCWordBeamSearch)
#                         word_beam_search_module = tf.load_op_library(r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\CTCWordBeamSearch-master\cpp\proj\TFWordBeamSearch.so')
#                         # decode using the "Words" mode of word beam search
#                         decoder = word_beam_search_module.word_beam_search(tf.nn.softmax(out, dim=2), 50, 'Words', 0.0, corpus.encode('utf8'), chars.encode('utf8'), wordChars.encode('utf8'))
                        
                    
                #decoderOuputToText function                   
                    "extract texts from output of CTC decoder"
                    # contains string of labels for each batch element
#                    batchSize = len(batch[batchNumber].imgs)
#                    encodedLabelStrs = [[] for i in range(batchSize)]

#                     # word beam search: label strings terminated by blank
#                     if decoderType == DecoderType.WordBeamSearch:
#                         blank=len(charList)
#                         for b in range(batchSize):
#                             #not sure what ctcOutput need to look at infer batch function in model
#                             for label in ctcOutput[b]:
#                                 if label==blank:
#                                     break
#                                 encodedLabelStrs[b].append(label)

#                     # TF decoders: label strings are contained in sparse tensor
#                     else:
#                         # ctc returns tuple, first element is SparseTensor 
#                         decoded=ctcOutput[0][0] 

#                         # go over all indices and save mapping: batch -> values
#                         idxDict = { b : [] for b in range(batchSize) }
#                         for (idx, idx2d) in enumerate(decoded.indices):
#                             label = decoded.values[idx]
#                             batchElement = idx2d[0] # index according to [b,t]
#                             encodedLabelStrs[batchElement].append(label)

                    # map labels to chars for all batch elements
#                    texts = [str().join([self.charList[c] for c in labelStr]) for labelStr in encodedLabelStrs]

                    
                    
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                        
                    running_loss += loss.item()
                    running_accuracy += batchAccuracy
                    running_probability += batchProb
                    #print (type(running_corrects))
                    #we might not have an accuracy rate since it's text
                    #running_corrects += torch.sum(preds == labs)#.cuda()
                    
            epoch_loss = running_loss / numberOfBatches
            epoch_acc = running_accuracy / numberOfBatches
            epoch_prob = running_probability / numberOfBatches
            if phase == 'val' and epoch == 0:
                test_batch = batch[0].imgs
                test_labels = wlabels[0]
            #if phase == 'val' and epoch_acc > best_acc:
            if phase == 'val' and epoch_prob > best_prob:
                best_prob = epoch_prob
                best_model_wts = copy.deepcopy(model.state_dict())
                model.load_state_dict(best_model_wts)
                torch.save({
                    'model': model,
                    'test_batch': test_batch,
                    'test_labels': test_labels
                }, r'C:\Users\User\fastai\courses\dl1\Handwriting recognition project\model\model.pt')
                print("Model saved")
            print(printStats(phase, epoch_loss, epoch_acc, epoch_prob, best_prob))
        if (epoch + 1) % 5 == 0:
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'best_prob': best_prob,
                'best_wts': best_model_wts
            }, PATH)
            print("Checkpoint saved")
            
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}hr {:.0f}m {:.0f}s'.format(
        time_elapsed//3600, (time_elapsed // 60) % 60, time_elapsed % 60))
    #use the latest model since no improvement in accuracy yet
    model.load_state_dict(best_model_wts)
    
    return model, test_batch, test_labels

# %%
def createLossAndOptimizer(net, learning_rate = 0.01):
    ctcloss = torch.nn.CTCLoss(reduction ='none').cuda()
    optimizer = torch.optim.Adam(net.parameters(), lr = learning_rate, weight_decay=0.00005)
    return ctcloss, optimizer

# %%
model_ft, test_batch, test_labels = train_model(Model().cuda(), num_epochs = 400, learning_rate = 0.01)
# Out:
# Epoch 0/399 : Mon May  6 19:36:17 2019 - 0h 1m
# ----------
#
# train Loss: 14.2759 Epoch Acc: 0.00E+00 Epoch Prob: 3.56E-13 Best Probability: 0.00E+00
# D:\Anaconda\lib\site-packages\torch\serialization.py:256: UserWarning: Couldn't retrieve source code for container of type Model. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Model saved
# val Loss: 11.9318 Epoch Acc: 0.00E+00 Epoch Prob: 7.39E-49 Best Probability: 7.39E-49
# Epoch 1/399 : Mon May  6 19:40:15 2019 - 0h 5m
# ----------
#
# train Loss: 12.0768 Epoch Acc: 0.00E+00 Epoch Prob: 1.03E-11 Best Probability: 7.39E-49
# Model saved
# val Loss: 10.0745 Epoch Acc: 0.00E+00 Epoch Prob: 1.62E-41 Best Probability: 1.62E-41
# Epoch 2/399 : Mon May  6 19:44:12 2019 - 0h 9m
# ----------
#
# train Loss: 9.9977 Epoch Acc: 0.00E+00 Epoch Prob: 8.70E-11 Best Probability: 1.62E-41
# Model saved
# val Loss: 9.0228 Epoch Acc: 0.00E+00 Epoch Prob: 1.89E-32 Best Probability: 1.89E-32
# Epoch 3/399 : Mon May  6 19:48:05 2019 - 0h 13m
# ----------
#
# train Loss: 7.7901 Epoch Acc: 0.00E+00 Epoch Prob: 5.86E-09 Best Probability: 1.89E-32
# val Loss: 6.7200 Epoch Acc: 0.00E+00 Epoch Prob: 1.10E-36 Best Probability: 1.89E-32
# Epoch 4/399 : Mon May  6 19:51:58 2019 - 0h 17m
# ----------
#
# train Loss: 6.0019 Epoch Acc: 0.00E+00 Epoch Prob: 7.53E-09 Best Probability: 1.89E-32
# val Loss: 5.1697 Epoch Acc: 0.00E+00 Epoch Prob: 1.35E-33 Best Probability: 1.89E-32
# Checkpoint saved
# Epoch 5/399 : Mon May  6 19:55:51 2019 - 0h 21m
# ----------
#
# train Loss: 4.9829 Epoch Acc: 0.00E+00 Epoch Prob: 8.52E-10 Best Probability: 1.89E-32
# val Loss: 4.6211 Epoch Acc: 0.00E+00 Epoch Prob: 4.06E-34 Best Probability: 1.89E-32
# Epoch 6/399 : Mon May  6 19:59:44 2019 - 0h 25m
# ----------
#
# train Loss: 4.3656 Epoch Acc: 0.00E+00 Epoch Prob: 3.16E-07 Best Probability: 1.89E-32
# val Loss: 4.1715 Epoch Acc: 0.00E+00 Epoch Prob: 8.21E-34 Best Probability: 1.89E-32
# Epoch 7/399 : Mon May  6 20:03:36 2019 - 0h 29m
# ----------
#
# train Loss: 3.9355 Epoch Acc: 0.00E+00 Epoch Prob: 8.85E-08 Best Probability: 1.89E-32
# val Loss: 4.0493 Epoch Acc: 0.00E+00 Epoch Prob: 3.03E-33 Best Probability: 1.89E-32
# Epoch 8/399 : Mon May  6 20:07:30 2019 - 0h 33m
# ----------
#
# train Loss: 3.6244 Epoch Acc: 0.00E+00 Epoch Prob: 5.55E-07 Best Probability: 1.89E-32
# val Loss: 3.7532 Epoch Acc: 0.00E+00 Epoch Prob: 1.18E-44 Best Probability: 1.89E-32
# Epoch 9/399 : Mon May  6 20:11:22 2019 - 0h 36m
# ----------
#
# train Loss: 3.4077 Epoch Acc: 0.00E+00 Epoch Prob: 4.42E-07 Best Probability: 1.89E-32
# Model saved
# val Loss: 3.6280 Epoch Acc: 0.00E+00 Epoch Prob: 2.93E-32 Best Probability: 2.93E-32
# Checkpoint saved
# Epoch 10/399 : Mon May  6 20:15:15 2019 - 0h 40m
# ----------
#
# train Loss: 3.2099 Epoch Acc: 0.00E+00 Epoch Prob: 9.57E-07 Best Probability: 2.93E-32
# Epoch 20/399 : Mon May  6 20:54:07 2019 - 1h 19m
# ----------
#
# train Loss: 2.3513 Epoch Acc: 0.00E+00 Epoch Prob: 3.55E-06 Best Probability: 8.28E-32
# val Loss: 3.6133 Epoch Acc: 0.00E+00 Epoch Prob: 4.91E-37 Best Probability: 8.28E-32
# Epoch 21/399 : Mon May  6 20:58:00 2019 - 1h 23m
# ----------
#
# train Loss: 2.2662 Epoch Acc: 0.00E+00 Epoch Prob: 1.03E-06 Best Probability: 8.28E-32
# Model saved
# val Loss: 3.4873 Epoch Acc: 0.00E+00 Epoch Prob: 3.48E-31 Best Probability: 3.48E-31
# Epoch 22/399 : Mon May  6 21:01:52 2019 - 1h 27m
# ----------
#
# train Loss: 2.2634 Epoch Acc: 0.00E+00 Epoch Prob: 3.67E-07 Best Probability: 3.48E-31
# val Loss: 3.4856 Epoch Acc: 0.00E+00 Epoch Prob: 7.71E-35 Best Probability: 3.48E-31
# Epoch 23/399 : Mon May  6 21:05:44 2019 - 1h 31m
# ----------
#
# train Loss: 2.2146 Epoch Acc: 0.00E+00 Epoch Prob: 9.50E-07 Best Probability: 3.48E-31
# val Loss: 3.5039 Epoch Acc: 0.00E+00 Epoch Prob: 6.99E-37 Best Probability: 3.48E-31
# Epoch 24/399 : Mon May  6 21:09:37 2019 - 1h 35m
# ----------
#
# train Loss: 2.2038 Epoch Acc: 0.00E+00 Epoch Prob: 1.57E-07 Best Probability: 3.48E-31
# val Loss: 3.4778 Epoch Acc: 0.00E+00 Epoch Prob: 3.99E-38 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 25/399 : Mon May  6 21:13:29 2019 - 1h 39m
# ----------
#
# train Loss: 2.1723 Epoch Acc: 0.00E+00 Epoch Prob: 2.03E-06 Best Probability: 3.48E-31
# val Loss: 3.5619 Epoch Acc: 0.00E+00 Epoch Prob: 1.62E-38 Best Probability: 3.48E-31
# Epoch 26/399 : Mon May  6 21:17:23 2019 - 1h 42m
# ----------
#
# train Loss: 2.1359 Epoch Acc: 0.00E+00 Epoch Prob: 2.94E-07 Best Probability: 3.48E-31
# val Loss: 3.6979 Epoch Acc: 0.00E+00 Epoch Prob: 8.72E-45 Best Probability: 3.48E-31
# Epoch 27/399 : Mon May  6 21:21:18 2019 - 1h 46m
# ----------
#
# train Loss: 2.0909 Epoch Acc: 0.00E+00 Epoch Prob: 2.10E-07 Best Probability: 3.48E-31
# val Loss: 3.4483 Epoch Acc: 0.00E+00 Epoch Prob: 9.17E-37 Best Probability: 3.48E-31
# Epoch 28/399 : Mon May  6 21:25:15 2019 - 1h 50m
# ----------
#
# train Loss: 2.0516 Epoch Acc: 0.00E+00 Epoch Prob: 2.42E-06 Best Probability: 3.48E-31
# val Loss: 3.5381 Epoch Acc: 0.00E+00 Epoch Prob: 2.62E-38 Best Probability: 3.48E-31
# Epoch 29/399 : Mon May  6 21:29:10 2019 - 1h 54m
# ----------
#
# train Loss: 2.0242 Epoch Acc: 0.00E+00 Epoch Prob: 1.95E-06 Best Probability: 3.48E-31
# val Loss: 3.5810 Epoch Acc: 0.00E+00 Epoch Prob: 3.04E-38 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 30/399 : Mon May  6 21:33:03 2019 - 1h 58m
# ----------
#
# train Loss: 2.0390 Epoch Acc: 0.00E+00 Epoch Prob: 2.76E-06 Best Probability: 3.48E-31
# val Loss: 3.4360 Epoch Acc: 0.00E+00 Epoch Prob: 3.92E-37 Best Probability: 3.48E-31
# Epoch 31/399 : Mon May  6 21:36:56 2019 - 2h 2m
# ----------
#
# train Loss: 2.0162 Epoch Acc: 0.00E+00 Epoch Prob: 1.10E-06 Best Probability: 3.48E-31
# val Loss: 3.4548 Epoch Acc: 0.00E+00 Epoch Prob: 8.13E-38 Best Probability: 3.48E-31
# Epoch 32/399 : Mon May  6 21:40:49 2019 - 2h 6m
# ----------
#
# train Loss: 1.9591 Epoch Acc: 4.00E-05 Epoch Prob: 4.16E-06 Best Probability: 3.48E-31
# val Loss: 3.5215 Epoch Acc: 0.00E+00 Epoch Prob: 2.39E-31 Best Probability: 3.48E-31
# Epoch 33/399 : Mon May  6 21:44:42 2019 - 2h 10m
# ----------
#
# train Loss: 1.9401 Epoch Acc: 4.00E-05 Epoch Prob: 6.61E-06 Best Probability: 3.48E-31
# val Loss: 3.6044 Epoch Acc: 0.00E+00 Epoch Prob: 2.58E-37 Best Probability: 3.48E-31
# Epoch 34/399 : Mon May  6 21:48:35 2019 - 2h 14m
# ----------
#
# train Loss: 1.9536 Epoch Acc: 0.00E+00 Epoch Prob: 5.21E-06 Best Probability: 3.48E-31
# val Loss: 3.4821 Epoch Acc: 0.00E+00 Epoch Prob: 1.73E-36 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 35/399 : Mon May  6 21:52:28 2019 - 2h 17m
# ----------
#
# train Loss: 1.9006 Epoch Acc: 4.00E-05 Epoch Prob: 4.65E-06 Best Probability: 3.48E-31
# val Loss: 3.8689 Epoch Acc: 0.00E+00 Epoch Prob: 4.45E-35 Best Probability: 3.48E-31
# Epoch 36/399 : Mon May  6 21:56:22 2019 - 2h 21m
# ----------
#
# train Loss: 1.8864 Epoch Acc: 0.00E+00 Epoch Prob: 2.77E-06 Best Probability: 3.48E-31
# val Loss: 3.6819 Epoch Acc: 0.00E+00 Epoch Prob: 1.57E-40 Best Probability: 3.48E-31
# Epoch 37/399 : Mon May  6 22:00:16 2019 - 2h 25m
# ----------
#
# train Loss: 1.8850 Epoch Acc: 0.00E+00 Epoch Prob: 6.30E-08 Best Probability: 3.48E-31
# val Loss: 3.6611 Epoch Acc: 0.00E+00 Epoch Prob: 5.40E-38 Best Probability: 3.48E-31
# Epoch 38/399 : Mon May  6 22:04:10 2019 - 2h 29m
# ----------
#
# train Loss: 1.8495 Epoch Acc: 0.00E+00 Epoch Prob: 7.44E-07 Best Probability: 3.48E-31
# val Loss: 3.5157 Epoch Acc: 0.00E+00 Epoch Prob: 8.04E-47 Best Probability: 3.48E-31
# val Loss: 3.6832 Epoch Acc: 0.00E+00 Epoch Prob: 1.35E-40 Best Probability: 3.48E-31
# Epoch 49/399 : Mon May  6 22:46:51 2019 - 3h 12m
# ----------
#
# train Loss: 1.7283 Epoch Acc: 4.00E-05 Epoch Prob: 1.42E-06 Best Probability: 3.48E-31
# val Loss: 3.5428 Epoch Acc: 0.00E+00 Epoch Prob: 6.20E-39 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 50/399 : Mon May  6 22:50:44 2019 - 3h 16m
# ----------
#
# train Loss: 1.7277 Epoch Acc: 0.00E+00 Epoch Prob: 1.60E-06 Best Probability: 3.48E-31
# val Loss: 3.5400 Epoch Acc: 0.00E+00 Epoch Prob: 4.89E-41 Best Probability: 3.48E-31
# Epoch 51/399 : Mon May  6 22:54:37 2019 - 3h 20m
# ----------
#
# train Loss: 1.6725 Epoch Acc: 0.00E+00 Epoch Prob: 3.10E-07 Best Probability: 3.48E-31
# val Loss: 3.6137 Epoch Acc: 0.00E+00 Epoch Prob: 1.22E-32 Best Probability: 3.48E-31
# Epoch 52/399 : Mon May  6 22:58:29 2019 - 3h 24m
# ----------
#
# train Loss: 1.6905 Epoch Acc: 0.00E+00 Epoch Prob: 1.44E-06 Best Probability: 3.48E-31
# val Loss: 3.4851 Epoch Acc: 0.00E+00 Epoch Prob: 9.89E-35 Best Probability: 3.48E-31
# Epoch 53/399 : Mon May  6 23:02:22 2019 - 3h 27m
# ----------
#
# train Loss: 1.6987 Epoch Acc: 0.00E+00 Epoch Prob: 1.50E-07 Best Probability: 3.48E-31
# val Loss: 3.6646 Epoch Acc: 0.00E+00 Epoch Prob: 3.69E-44 Best Probability: 3.48E-31
# Epoch 54/399 : Mon May  6 23:06:14 2019 - 3h 31m
# ----------
#
# train Loss: 1.7047 Epoch Acc: 0.00E+00 Epoch Prob: 1.44E-07 Best Probability: 3.48E-31
# val Loss: 3.6945 Epoch Acc: 0.00E+00 Epoch Prob: 7.12E-34 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 55/399 : Mon May  6 23:10:07 2019 - 3h 35m
# ----------
#
# train Loss: 1.6297 Epoch Acc: 4.00E-05 Epoch Prob: 1.54E-06 Best Probability: 3.48E-31
# val Loss: 3.5351 Epoch Acc: 0.00E+00 Epoch Prob: 9.30E-40 Best Probability: 3.48E-31
# Epoch 56/399 : Mon May  6 23:13:59 2019 - 3h 39m
# ----------
#
# train Loss: 1.6705 Epoch Acc: 0.00E+00 Epoch Prob: 2.03E-07 Best Probability: 3.48E-31
# val Loss: 3.5757 Epoch Acc: 0.00E+00 Epoch Prob: 6.07E-45 Best Probability: 3.48E-31
# Epoch 57/399 : Mon May  6 23:17:51 2019 - 3h 43m
# ----------
#
# train Loss: 1.6883 Epoch Acc: 0.00E+00 Epoch Prob: 1.09E-06 Best Probability: 3.48E-31
# val Loss: 3.5361 Epoch Acc: 0.00E+00 Epoch Prob: 2.97E-41 Best Probability: 3.48E-31
# Epoch 58/399 : Mon May  6 23:21:44 2019 - 3h 47m
# ----------
#
# train Loss: 1.6404 Epoch Acc: 4.00E-05 Epoch Prob: 2.13E-06 Best Probability: 3.48E-31
# val Loss: 3.5541 Epoch Acc: 0.00E+00 Epoch Prob: 3.61E-40 Best Probability: 3.48E-31
# Epoch 59/399 : Mon May  6 23:25:41 2019 - 3h 51m
# ----------
#
# train Loss: 1.6322 Epoch Acc: 4.00E-05 Epoch Prob: 1.00E-05 Best Probability: 3.48E-31
# val Loss: 3.7218 Epoch Acc: 0.00E+00 Epoch Prob: 1.05E-34 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 60/399 : Mon May  6 23:29:45 2019 - 3h 55m
# ----------
#
# train Loss: 1.6399 Epoch Acc: 0.00E+00 Epoch Prob: 1.80E-06 Best Probability: 3.48E-31
# val Loss: 3.5500 Epoch Acc: 0.00E+00 Epoch Prob: 1.16E-44 Best Probability: 3.48E-31
# Epoch 61/399 : Mon May  6 23:33:56 2019 - 3h 59m
# ----------
#
# train Loss: 1.5921 Epoch Acc: 0.00E+00 Epoch Prob: 5.34E-07 Best Probability: 3.48E-31
# val Loss: 3.6251 Epoch Acc: 0.00E+00 Epoch Prob: 2.65E-43 Best Probability: 3.48E-31
# Epoch 62/399 : Mon May  6 23:38:06 2019 - 4h 3m
# ----------
#
# train Loss: 1.5767 Epoch Acc: 0.00E+00 Epoch Prob: 4.48E-08 Best Probability: 3.48E-31
# val Loss: 3.5036 Epoch Acc: 0.00E+00 Epoch Prob: 4.22E-37 Best Probability: 3.48E-31
# Epoch 63/399 : Mon May  6 23:41:58 2019 - 4h 7m
# ----------
#
# train Loss: 1.5859 Epoch Acc: 0.00E+00 Epoch Prob: 4.39E-07 Best Probability: 3.48E-31
# val Loss: 3.6617 Epoch Acc: 0.00E+00 Epoch Prob: 1.40E-44 Best Probability: 3.48E-31
# Epoch 64/399 : Mon May  6 23:45:50 2019 - 4h 11m
# ----------
#
# train Loss: 1.6047 Epoch Acc: 4.00E-05 Epoch Prob: 1.08E-05 Best Probability: 3.48E-31
# val Loss: 3.6380 Epoch Acc: 0.00E+00 Epoch Prob: 4.39E-40 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 65/399 : Mon May  6 23:49:40 2019 - 4h 15m
# ----------
#
# train Loss: 1.6119 Epoch Acc: 0.00E+00 Epoch Prob: 2.22E-07 Best Probability: 3.48E-31
# val Loss: 3.5577 Epoch Acc: 0.00E+00 Epoch Prob: 3.96E-40 Best Probability: 3.48E-31
# Epoch 66/399 : Mon May  6 23:53:31 2019 - 4h 19m
# ----------
#
# train Loss: 1.6044 Epoch Acc: 0.00E+00 Epoch Prob: 1.50E-06 Best Probability: 3.48E-31
# val Loss: 3.5281 Epoch Acc: 0.00E+00 Epoch Prob: 1.60E-40 Best Probability: 3.48E-31
# Epoch 67/399 : Mon May  6 23:57:22 2019 - 4h 22m
# ----------
#
# train Loss: 1.5711 Epoch Acc: 4.00E-05 Epoch Prob: 7.14E-06 Best Probability: 3.48E-31
# val Loss: 3.6976 Epoch Acc: 0.00E+00 Epoch Prob: 3.95E-35 Best Probability: 3.48E-31
# Epoch 68/399 : Tue May  7 00:01:12 2019 - 4h 26m
# ----------
#
# train Loss: 1.5676 Epoch Acc: 0.00E+00 Epoch Prob: 3.24E-06 Best Probability: 3.48E-31
# val Loss: 3.6112 Epoch Acc: 0.00E+00 Epoch Prob: 1.01E-38 Best Probability: 3.48E-31
# Epoch 69/399 : Tue May  7 00:05:02 2019 - 4h 30m
# ----------
#
# train Loss: 1.5568 Epoch Acc: 0.00E+00 Epoch Prob: 5.11E-06 Best Probability: 3.48E-31
# val Loss: 3.7520 Epoch Acc: 0.00E+00 Epoch Prob: 1.45E-38 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 70/399 : Tue May  7 00:08:53 2019 - 4h 34m
# ----------
#
# train Loss: 1.5372 Epoch Acc: 0.00E+00 Epoch Prob: 3.78E-07 Best Probability: 3.48E-31
# val Loss: 3.8075 Epoch Acc: 0.00E+00 Epoch Prob: 1.57E-44 Best Probability: 3.48E-31
# Epoch 71/399 : Tue May  7 00:12:43 2019 - 4h 38m
# ----------
#
# train Loss: 1.5748 Epoch Acc: 4.00E-05 Epoch Prob: 2.30E-06 Best Probability: 3.48E-31
# val Loss: 3.7207 Epoch Acc: 0.00E+00 Epoch Prob: 2.11E-35 Best Probability: 3.48E-31
# Epoch 72/399 : Tue May  7 00:16:34 2019 - 4h 42m
# ----------
#
# train Loss: 1.5701 Epoch Acc: 0.00E+00 Epoch Prob: 1.23E-06 Best Probability: 3.48E-31
# val Loss: 3.4998 Epoch Acc: 0.00E+00 Epoch Prob: 1.92E-48 Best Probability: 3.48E-31
# Epoch 73/399 : Tue May  7 00:20:25 2019 - 4h 45m
# ----------
#
# train Loss: 1.5485 Epoch Acc: 0.00E+00 Epoch Prob: 1.97E-07 Best Probability: 3.48E-31
# val Loss: 3.5486 Epoch Acc: 0.00E+00 Epoch Prob: 8.33E-40 Best Probability: 3.48E-31
# Epoch 74/399 : Tue May  7 00:24:16 2019 - 4h 49m
# ----------
#
# train Loss: 1.5744 Epoch Acc: 0.00E+00 Epoch Prob: 5.73E-06 Best Probability: 3.48E-31
# val Loss: 3.6801 Epoch Acc: 0.00E+00 Epoch Prob: 1.37E-36 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 75/399 : Tue May  7 00:28:07 2019 - 4h 53m
# ----------
#
# train Loss: 1.5417 Epoch Acc: 0.00E+00 Epoch Prob: 4.70E-06 Best Probability: 3.48E-31
# val Loss: 3.6789 Epoch Acc: 0.00E+00 Epoch Prob: 1.42E-40 Best Probability: 3.48E-31
# Epoch 76/399 : Tue May  7 00:31:57 2019 - 4h 57m
# ----------
#
# train Loss: 1.5357 Epoch Acc: 4.00E-05 Epoch Prob: 4.90E-06 Best Probability: 3.48E-31
# val Loss: 3.6240 Epoch Acc: 0.00E+00 Epoch Prob: 4.31E-41 Best Probability: 3.48E-31
# Epoch 77/399 : Tue May  7 00:35:47 2019 - 5h 1m
# ----------
#
# train Loss: 1.5140 Epoch Acc: 0.00E+00 Epoch Prob: 6.52E-06 Best Probability: 3.48E-31
# val Loss: 3.6067 Epoch Acc: 0.00E+00 Epoch Prob: 2.26E-43 Best Probability: 3.48E-31
# Epoch 78/399 : Tue May  7 00:39:37 2019 - 5h 5m
# ----------
#
# train Loss: 1.5429 Epoch Acc: 0.00E+00 Epoch Prob: 4.68E-06 Best Probability: 3.48E-31
# val Loss: 3.6883 Epoch Acc: 0.00E+00 Epoch Prob: 4.35E-48 Best Probability: 3.48E-31
# Epoch 79/399 : Tue May  7 00:43:28 2019 - 5h 8m
# ----------
#
# train Loss: 1.5244 Epoch Acc: 0.00E+00 Epoch Prob: 2.72E-06 Best Probability: 3.48E-31
# val Loss: 3.6012 Epoch Acc: 0.00E+00 Epoch Prob: 1.13E-35 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 80/399 : Tue May  7 00:47:19 2019 - 5h 12m
# ----------
#
# train Loss: 1.5607 Epoch Acc: 4.00E-05 Epoch Prob: 4.50E-06 Best Probability: 3.48E-31
# val Loss: 3.5712 Epoch Acc: 0.00E+00 Epoch Prob: 2.46E-45 Best Probability: 3.48E-31
# Epoch 81/399 : Tue May  7 00:51:09 2019 - 5h 16m
# ----------
#
# train Loss: 1.5376 Epoch Acc: 0.00E+00 Epoch Prob: 1.03E-06 Best Probability: 3.48E-31
# val Loss: 3.6372 Epoch Acc: 0.00E+00 Epoch Prob: 7.14E-46 Best Probability: 3.48E-31
# Epoch 82/399 : Tue May  7 00:55:00 2019 - 5h 20m
# ----------
#
# train Loss: 1.4878 Epoch Acc: 0.00E+00 Epoch Prob: 1.50E-06 Best Probability: 3.48E-31
# val Loss: 3.6352 Epoch Acc: 0.00E+00 Epoch Prob: 5.25E-40 Best Probability: 3.48E-31
# Epoch 83/399 : Tue May  7 00:58:50 2019 - 5h 24m
# ----------
#
# train Loss: 1.5257 Epoch Acc: 0.00E+00 Epoch Prob: 2.61E-07 Best Probability: 3.48E-31
# val Loss: 3.5474 Epoch Acc: 0.00E+00 Epoch Prob: 2.40E-39 Best Probability: 3.48E-31
# Epoch 84/399 : Tue May  7 01:02:40 2019 - 5h 28m
# ----------
#
# train Loss: 1.5159 Epoch Acc: 0.00E+00 Epoch Prob: 3.22E-07 Best Probability: 3.48E-31
# val Loss: 3.7566 Epoch Acc: 0.00E+00 Epoch Prob: 1.94E-49 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 85/399 : Tue May  7 01:06:31 2019 - 5h 32m
# ----------
#
# train Loss: 1.4959 Epoch Acc: 4.00E-05 Epoch Prob: 5.96E-06 Best Probability: 3.48E-31
# val Loss: 3.5806 Epoch Acc: 0.00E+00 Epoch Prob: 1.21E-47 Best Probability: 3.48E-31
# Epoch 86/399 : Tue May  7 01:10:22 2019 - 5h 35m
# ----------
#
# train Loss: 1.5095 Epoch Acc: 0.00E+00 Epoch Prob: 5.81E-07 Best Probability: 3.48E-31
# val Loss: 3.5516 Epoch Acc: 0.00E+00 Epoch Prob: 5.41E-38 Best Probability: 3.48E-31
# Epoch 87/399 : Tue May  7 01:14:11 2019 - 5h 39m
# ----------
#
# train Loss: 1.5308 Epoch Acc: 0.00E+00 Epoch Prob: 2.31E-06 Best Probability: 3.48E-31
# val Loss: 3.5985 Epoch Acc: 0.00E+00 Epoch Prob: 3.04E-44 Best Probability: 3.48E-31
# Epoch 88/399 : Tue May  7 01:18:02 2019 - 5h 43m
# ----------
#
# train Loss: 1.4962 Epoch Acc: 0.00E+00 Epoch Prob: 1.83E-09 Best Probability: 3.48E-31
# val Loss: 3.7354 Epoch Acc: 0.00E+00 Epoch Prob: 3.79E-42 Best Probability: 3.48E-31
# Epoch 89/399 : Tue May  7 01:21:52 2019 - 5h 47m
# ----------
#
# train Loss: 1.4386 Epoch Acc: 0.00E+00 Epoch Prob: 2.05E-06 Best Probability: 3.48E-31
# val Loss: 3.7839 Epoch Acc: 0.00E+00 Epoch Prob: 6.06E-42 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 90/399 : Tue May  7 01:25:42 2019 - 5h 51m
# ----------
#
# train Loss: 1.4343 Epoch Acc: 4.00E-05 Epoch Prob: 2.32E-06 Best Probability: 3.48E-31
# val Loss: 3.6924 Epoch Acc: 0.00E+00 Epoch Prob: 9.83E-45 Best Probability: 3.48E-31
# Epoch 91/399 : Tue May  7 01:29:33 2019 - 5h 55m
# ----------
#
# train Loss: 1.4936 Epoch Acc: 4.00E-05 Epoch Prob: 7.55E-06 Best Probability: 3.48E-31
# val Loss: 3.9071 Epoch Acc: 0.00E+00 Epoch Prob: 4.26E-40 Best Probability: 3.48E-31
# Epoch 92/399 : Tue May  7 01:33:24 2019 - 5h 58m
# ----------
#
# train Loss: 1.5149 Epoch Acc: 0.00E+00 Epoch Prob: 4.28E-06 Best Probability: 3.48E-31
# val Loss: 3.6478 Epoch Acc: 0.00E+00 Epoch Prob: 1.36E-42 Best Probability: 3.48E-31
# Epoch 93/399 : Tue May  7 01:37:14 2019 - 6h 2m
# ----------
#
# train Loss: 1.4894 Epoch Acc: 0.00E+00 Epoch Prob: 1.77E-06 Best Probability: 3.48E-31
# val Loss: 3.7846 Epoch Acc: 0.00E+00 Epoch Prob: 5.43E-45 Best Probability: 3.48E-31
# Epoch 94/399 : Tue May  7 01:41:05 2019 - 6h 6m
# ----------
#
# train Loss: 1.4572 Epoch Acc: 0.00E+00 Epoch Prob: 2.35E-07 Best Probability: 3.48E-31
# val Loss: 3.4984 Epoch Acc: 0.00E+00 Epoch Prob: 9.22E-36 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 95/399 : Tue May  7 01:44:56 2019 - 6h 10m
# ----------
#
# train Loss: 1.4751 Epoch Acc: 0.00E+00 Epoch Prob: 5.88E-07 Best Probability: 3.48E-31
# val Loss: 3.6642 Epoch Acc: 0.00E+00 Epoch Prob: 9.12E-37 Best Probability: 3.48E-31
# Checkpoint saved
# Epoch 115/399 : Tue May  7 03:01:50 2019 - 7h 27m
# ----------
#
# train Loss: 1.4355 Epoch Acc: 4.00E-05 Epoch Prob: 1.34E-05 Best Probability: 1.85E-30
# val Loss: 3.6566 Epoch Acc: 0.00E+00 Epoch Prob: 4.18E-35 Best Probability: 1.85E-30
# Epoch 116/399 : Tue May  7 03:05:41 2019 - 7h 31m
# ----------
#
# train Loss: 1.4575 Epoch Acc: 0.00E+00 Epoch Prob: 1.42E-06 Best Probability: 1.85E-30
# val Loss: 3.7703 Epoch Acc: 0.00E+00 Epoch Prob: 3.17E-38 Best Probability: 1.85E-30
# Epoch 117/399 : Tue May  7 03:09:32 2019 - 7h 35m
# ----------
#
# train Loss: 1.4721 Epoch Acc: 0.00E+00 Epoch Prob: 1.33E-07 Best Probability: 1.85E-30
# val Loss: 3.4534 Epoch Acc: 0.00E+00 Epoch Prob: 5.21E-44 Best Probability: 1.85E-30
# Epoch 118/399 : Tue May  7 03:13:22 2019 - 7h 38m
# ----------
#
# train Loss: 1.4215 Epoch Acc: 4.00E-05 Epoch Prob: 4.42E-06 Best Probability: 1.85E-30
# val Loss: 3.5245 Epoch Acc: 0.00E+00 Epoch Prob: 8.03E-48 Best Probability: 1.85E-30
# Epoch 119/399 : Tue May  7 03:17:13 2019 - 7h 42m
# ----------
#
# train Loss: 1.4765 Epoch Acc: 0.00E+00 Epoch Prob: 8.29E-07 Best Probability: 1.85E-30
# val Loss: 3.5100 Epoch Acc: 0.00E+00 Epoch Prob: 1.03E-45 Best Probability: 1.85E-30
# Checkpoint saved
# Epoch 120/399 : Tue May  7 03:21:11 2019 - 7h 46m
# ----------
#
# train Loss: 1.4049 Epoch Acc: 0.00E+00 Epoch Prob: 1.46E-06 Best Probability: 1.85E-30
# val Loss: 3.5899 Epoch Acc: 0.00E+00 Epoch Prob: 2.90E-43 Best Probability: 1.85E-30
# Epoch 121/399 : Tue May  7 03:25:04 2019 - 7h 50m
# ----------
#
# train Loss: 1.4186 Epoch Acc: 0.00E+00 Epoch Prob: 1.50E-06 Best Probability: 1.85E-30
# val Loss: 3.5601 Epoch Acc: 0.00E+00 Epoch Prob: 5.84E-47 Best Probability: 1.85E-30
# Epoch 122/399 : Tue May  7 03:28:54 2019 - 7h 54m
# ----------
#
# train Loss: 1.4561 Epoch Acc: 0.00E+00 Epoch Prob: 3.18E-06 Best Probability: 1.85E-30
# val Loss: 3.6957 Epoch Acc: 0.00E+00 Epoch Prob: 2.32E-39 Best Probability: 1.85E-30
# Epoch 123/399 : Tue May  7 03:32:44 2019 - 7h 58m
# ----------
#
# train Loss: 1.4194 Epoch Acc: 0.00E+00 Epoch Prob: 2.57E-07 Best Probability: 1.85E-30
# val Loss: 3.5869 Epoch Acc: 0.00E+00 Epoch Prob: 2.27E-42 Best Probability: 1.85E-30
# Epoch 124/399 : Tue May  7 03:36:35 2019 - 8h 2m
# ----------
#
# train Loss: 1.4232 Epoch Acc: 0.00E+00 Epoch Prob: 1.86E-06 Best Probability: 1.85E-30
# val Loss: 3.7530 Epoch Acc: 0.00E+00 Epoch Prob: 3.82E-42 Best Probability: 1.85E-30
# Checkpoint saved
# Epoch 125/399 : Tue May  7 03:40:25 2019 - 8h 5m
# ----------
#
# train Loss: 1.4239 Epoch Acc: 4.00E-05 Epoch Prob: 4.83E-06 Best Probability: 1.85E-30
# val Loss: 3.6200 Epoch Acc: 0.00E+00 Epoch Prob: 2.71E-39 Best Probability: 1.85E-30
# Epoch 126/399 : Tue May  7 03:44:16 2019 - 8h 9m
# ----------
#
# train Loss: 1.4575 Epoch Acc: 0.00E+00 Epoch Prob: 2.22E-07 Best Probability: 1.85E-30
# val Loss: 3.5299 Epoch Acc: 0.00E+00 Epoch Prob: 1.67E-43 Best Probability: 1.85E-30
# Epoch 127/399 : Tue May  7 03:48:07 2019 - 8h 13m
# ----------
#
# train Loss: 1.4445 Epoch Acc: 4.00E-05 Epoch Prob: 1.85E-06 Best Probability: 1.85E-30
# val Loss: 3.5939 Epoch Acc: 0.00E+00 Epoch Prob: 1.43E-42 Best Probability: 1.85E-30
# Epoch 128/399 : Tue May  7 03:51:57 2019 - 8h 17m
# ----------
#
# train Loss: 1.3960 Epoch Acc: 0.00E+00 Epoch Prob: 5.78E-07 Best Probability: 1.85E-30
# val Loss: 3.6293 Epoch Acc: 0.00E+00 Epoch Prob: 4.72E-42 Best Probability: 1.85E-30
# Epoch 129/399 : Tue May  7 03:55:47 2019 - 8h 21m
# ----------
#
# train Loss: 1.3550 Epoch Acc: 0.00E+00 Epoch Prob: 2.60E-06 Best Probability: 1.85E-30
# val Loss: 3.6707 Epoch Acc: 0.00E+00 Epoch Prob: 6.71E-41 Best Probability: 1.85E-30
# Checkpoint saved
# Epoch 130/399 : Tue May  7 03:59:37 2019 - 8h 25m
# ----------
#
# train Loss: 1.3901 Epoch Acc: 0.00E+00 Epoch Prob: 9.07E-07 Best Probability: 1.85E-30
# val Loss: 3.7301 Epoch Acc: 0.00E+00 Epoch Prob: 7.73E-34 Best Probability: 1.85E-30
# Epoch 131/399 : Tue May  7 04:03:28 2019 - 8h 28m
# ----------
#
# train Loss: 1.4487 Epoch Acc: 0.00E+00 Epoch Prob: 5.55E-07 Best Probability: 1.85E-30
# val Loss: 3.5401 Epoch Acc: 0.00E+00 Epoch Prob: 2.26E-44 Best Probability: 1.85E-30
# Epoch 132/399 : Tue May  7 04:07:19 2019 - 8h 32m
# ----------
#
# train Loss: 1.3871 Epoch Acc: 0.00E+00 Epoch Prob: 3.20E-07 Best Probability: 1.85E-30
# val Loss: 3.6254 Epoch Acc: 0.00E+00 Epoch Prob: 5.19E-34 Best Probability: 1.85E-30
# Epoch 133/399 : Tue May  7 04:11:09 2019 - 8h 36m
# ----------
#
# train Loss: 1.4451 Epoch Acc: 4.00E-05 Epoch Prob: 7.83E-06 Best Probability: 1.85E-30
# val Loss: 3.6481 Epoch Acc: 0.00E+00 Epoch Prob: 1.93E-39 Best Probability: 1.85E-30
# Epoch 134/399 : Tue May  7 04:15:00 2019 - 8h 40m
# ----------
#
# train Loss: 1.4172 Epoch Acc: 0.00E+00 Epoch Prob: 1.22E-06 Best Probability: 1.85E-30
# val Loss: 3.7666 Epoch Acc: 0.00E+00 Epoch Prob: 4.28E-44 Best Probability: 1.85E-30
# Checkpoint saved
# Epoch 135/399 : Tue May  7 04:18:50 2019 - 8h 44m
# ----------
#
# train Loss: 1.3819 Epoch Acc: 4.00E-05 Epoch Prob: 7.94E-06 Best Probability: 1.85E-30
# val Loss: 3.6458 Epoch Acc: 0.00E+00 Epoch Prob: 6.77E-42 Best Probability: 1.85E-30
# Epoch 136/399 : Tue May  7 04:22:41 2019 - 8h 48m
# ----------
#
# train Loss: 1.4202 Epoch Acc: 0.00E+00 Epoch Prob: 1.86E-06 Best Probability: 1.85E-30
# val Loss: 3.8275 Epoch Acc: 0.00E+00 Epoch Prob: 2.36E-37 Best Probability: 1.85E-30
# Epoch 137/399 : Tue May  7 04:26:31 2019 - 8h 52m
# ----------
#
# train Loss: 1.4014 Epoch Acc: 4.00E-05 Epoch Prob: 6.31E-06 Best Probability: 1.85E-30
# val Loss: 3.6378 Epoch Acc: 0.00E+00 Epoch Prob: 2.45E-36 Best Probability: 1.85E-30
# Epoch 138/399 : Tue May  7 04:30:22 2019 - 8h 55m
# ----------
#
# train Loss: 1.3806 Epoch Acc: 4.00E-05 Epoch Prob: 1.46E-05 Best Probability: 1.85E-30
# val Loss: 3.5385 Epoch Acc: 0.00E+00 Epoch Prob: 1.47E-34 Best Probability: 1.85E-30
# Epoch 139/399 : Tue May  7 04:34:12 2019 - 8h 59m
# ----------
#
# train Loss: 1.4310 Epoch Acc: 0.00E+00 Epoch Prob: 6.46E-06 Best Probability: 1.85E-30
# val Loss: 3.6842 Epoch Acc: 0.00E+00 Epoch Prob: 1.54E-36 Best Probability: 1.85E-30
# Checkpoint saved
# Epoch 140/399 : Tue May  7 04:38:04 2019 - 9h 3m
# ----------
#
# train Loss: 1.3865 Epoch Acc: 4.00E-05 Epoch Prob: 9.09E-06 Best Probability: 1.85E-30
# val Loss: 3.6296 Epoch Acc: 0.00E+00 Epoch Prob: 4.87E-40 Best Probability: 1.85E-30
# Epoch 141/399 : Tue May  7 04:41:55 2019 - 9h 7m
# ----------
#
# train Loss: 1.3529 Epoch Acc: 0.00E+00 Epoch Prob: 2.73E-06 Best Probability: 1.85E-30
# val Loss: 3.6327 Epoch Acc: 0.00E+00 Epoch Prob: 1.85E-34 Best Probability: 1.85E-30
# Epoch 142/399 : Tue May  7 04:45:45 2019 - 9h 11m
# ----------
#
# train Loss: 1.3749 Epoch Acc: 0.00E+00 Epoch Prob: 1.65E-06 Best Probability: 1.85E-30
# val Loss: 3.5402 Epoch Acc: 0.00E+00 Epoch Prob: 3.77E-39 Best Probability: 1.85E-30
# Epoch 143/399 : Tue May  7 04:49:35 2019 - 9h 15m
# ----------
#
# train Loss: 1.3822 Epoch Acc: 0.00E+00 Epoch Prob: 4.06E-06 Best Probability: 1.85E-30
# val Loss: 3.6661 Epoch Acc: 0.00E+00 Epoch Prob: 3.30E-37 Best Probability: 1.85E-30
# Epoch 144/399 : Tue May  7 04:53:25 2019 - 9h 18m
# ----------
#
# train Loss: 1.3858 Epoch Acc: 0.00E+00 Epoch Prob: 1.28E-06 Best Probability: 1.85E-30
# val Loss: 3.5941 Epoch Acc: 0.00E+00 Epoch Prob: 1.04E-37 Best Probability: 1.85E-30
# Checkpoint saved
# Epoch 145/399 : Tue May  7 04:57:16 2019 - 9h 22m
# ----------
#
# train Loss: 1.3619 Epoch Acc: 0.00E+00 Epoch Prob: 2.04E-06 Best Probability: 1.85E-30
# val Loss: 3.7795 Epoch Acc: 0.00E+00 Epoch Prob: 1.37E-39 Best Probability: 1.85E-30
# Epoch 146/399 : Tue May  7 05:01:07 2019 - 9h 26m
# ----------
#
# train Loss: 1.4327 Epoch Acc: 0.00E+00 Epoch Prob: 3.34E-06 Best Probability: 1.85E-30
# val Loss: 3.5077 Epoch Acc: 0.00E+00 Epoch Prob: 6.41E-35 Best Probability: 1.85E-30
# Epoch 147/399 : Tue May  7 05:04:57 2019 - 9h 30m
# ----------
#
# train Loss: 1.3743 Epoch Acc: 0.00E+00 Epoch Prob: 3.38E-06 Best Probability: 1.85E-30
# val Loss: 3.5140 Epoch Acc: 0.00E+00 Epoch Prob: 2.59E-32 Best Probability: 1.85E-30
# Epoch 148/399 : Tue May  7 05:08:47 2019 - 9h 34m
# ----------
#
# train Loss: 1.4056 Epoch Acc: 4.00E-05 Epoch Prob: 7.80E-06 Best Probability: 1.85E-30
# val Loss: 3.5350 Epoch Acc: 0.00E+00 Epoch Prob: 5.18E-32 Best Probability: 1.85E-30
# Epoch 149/399 : Tue May  7 05:12:38 2019 - 9h 38m
# ----------
#
# train Loss: 1.3429 Epoch Acc: 4.00E-05 Epoch Prob: 9.53E-06 Best Probability: 1.85E-30
# Model saved
# val Loss: 3.4655 Epoch Acc: 0.00E+00 Epoch Prob: 1.62E-29 Best Probability: 1.62E-29
# Checkpoint saved
# Epoch 150/399 : Tue May  7 05:16:27 2019 - 9h 41m
# ----------
#
# train Loss: 1.3255 Epoch Acc: 0.00E+00 Epoch Prob: 1.12E-06 Best Probability: 1.62E-29
# val Loss: 3.6509 Epoch Acc: 0.00E+00 Epoch Prob: 1.08E-42 Best Probability: 1.62E-29
# Epoch 151/399 : Tue May  7 05:20:18 2019 - 9h 45m
# ----------
#
# train Loss: 1.4188 Epoch Acc: 4.00E-05 Epoch Prob: 1.10E-05 Best Probability: 1.62E-29
# val Loss: 3.6286 Epoch Acc: 0.00E+00 Epoch Prob: 2.92E-32 Best Probability: 1.62E-29
# Epoch 152/399 : Tue May  7 05:24:09 2019 - 9h 49m
# ----------
#
# train Loss: 1.3854 Epoch Acc: 0.00E+00 Epoch Prob: 5.46E-06 Best Probability: 1.62E-29
# ----------
#
# train Loss: 1.3842 Epoch Acc: 4.00E-05 Epoch Prob: 8.53E-06 Best Probability: 1.38E-28
# val Loss: 3.7518 Epoch Acc: 0.00E+00 Epoch Prob: 3.50E-42 Best Probability: 1.38E-28
# Epoch 163/399 : Tue May  7 06:06:24 2019 - 10h 31m
# ----------
#
# train Loss: 1.3740 Epoch Acc: 4.00E-05 Epoch Prob: 6.03E-06 Best Probability: 1.38E-28
# val Loss: 3.6559 Epoch Acc: 0.00E+00 Epoch Prob: 2.51E-41 Best Probability: 1.38E-28
# Epoch 164/399 : Tue May  7 06:10:13 2019 - 10h 35m
# ----------
#
# train Loss: 1.3543 Epoch Acc: 4.00E-05 Epoch Prob: 3.79E-06 Best Probability: 1.38E-28
# val Loss: 3.5236 Epoch Acc: 0.00E+00 Epoch Prob: 1.47E-35 Best Probability: 1.38E-28
# Checkpoint saved
# Epoch 165/399 : Tue May  7 06:14:04 2019 - 10h 39m
# ----------
#
# train Loss: 1.3376 Epoch Acc: 0.00E+00 Epoch Prob: 2.61E-06 Best Probability: 1.38E-28
# val Loss: 3.6828 Epoch Acc: 0.00E+00 Epoch Prob: 6.43E-41 Best Probability: 1.38E-28
# Epoch 166/399 : Tue May  7 06:17:54 2019 - 10h 43m
# ----------
#
# train Loss: 1.3941 Epoch Acc: 0.00E+00 Epoch Prob: 5.33E-06 Best Probability: 1.38E-28
# val Loss: 3.6104 Epoch Acc: 0.00E+00 Epoch Prob: 1.09E-39 Best Probability: 1.38E-28
# Epoch 167/399 : Tue May  7 06:21:45 2019 - 10h 47m
# ----------
#
# train Loss: 1.3455 Epoch Acc: 0.00E+00 Epoch Prob: 1.24E-06 Best Probability: 1.38E-28
# val Loss: 3.8633 Epoch Acc: 0.00E+00 Epoch Prob: 2.38E-46 Best Probability: 1.38E-28
# Epoch 168/399 : Tue May  7 06:25:35 2019 - 10h 51m
# ----------
#
# train Loss: 1.3660 Epoch Acc: 0.00E+00 Epoch Prob: 1.05E-06 Best Probability: 1.38E-28
# Model saved
# val Loss: 3.8747 Epoch Acc: 0.00E+00 Epoch Prob: 1.13E-27 Best Probability: 1.13E-27
# Epoch 169/399 : Tue May  7 06:29:25 2019 - 10h 54m
# ----------
#
# train Loss: 1.3446 Epoch Acc: 4.00E-05 Epoch Prob: 2.71E-06 Best Probability: 1.13E-27
# val Loss: 3.5269 Epoch Acc: 0.00E+00 Epoch Prob: 3.00E-40 Best Probability: 1.13E-27
# Checkpoint saved
# Epoch 170/399 : Tue May  7 06:33:17 2019 - 10h 58m
# ----------
#
# train Loss: 1.3409 Epoch Acc: 4.00E-05 Epoch Prob: 4.24E-06 Best Probability: 1.13E-27
# val Loss: 3.6278 Epoch Acc: 0.00E+00 Epoch Prob: 4.64E-40 Best Probability: 1.13E-27
# Epoch 171/399 : Tue May  7 06:37:07 2019 - 11h 2m
# ----------
#
# train Loss: 1.3864 Epoch Acc: 0.00E+00 Epoch Prob: 4.12E-07 Best Probability: 1.13E-27
# Epoch 181/399 : Tue May  7 07:15:30 2019 - 11h 41m
# ----------
#
# train Loss: 1.3545 Epoch Acc: 0.00E+00 Epoch Prob: 5.89E-06 Best Probability: 1.13E-27
# val Loss: 3.6074 Epoch Acc: 0.00E+00 Epoch Prob: 1.64E-38 Best Probability: 1.13E-27
# Epoch 182/399 : Tue May  7 07:19:21 2019 - 11h 44m
# ----------
#
# train Loss: 1.3305 Epoch Acc: 0.00E+00 Epoch Prob: 2.61E-07 Best Probability: 1.13E-27
# val Loss: 3.6977 Epoch Acc: 0.00E+00 Epoch Prob: 8.29E-40 Best Probability: 1.13E-27
# Epoch 183/399 : Tue May  7 07:23:11 2019 - 11h 48m
# ----------
#
# train Loss: 1.3477 Epoch Acc: 0.00E+00 Epoch Prob: 1.82E-07 Best Probability: 1.13E-27
# val Loss: 3.5400 Epoch Acc: 0.00E+00 Epoch Prob: 8.82E-36 Best Probability: 1.13E-27
# Epoch 184/399 : Tue May  7 07:27:01 2019 - 11h 52m
# ----------
#
# train Loss: 1.3975 Epoch Acc: 0.00E+00 Epoch Prob: 3.11E-07 Best Probability: 1.13E-27
# val Loss: 3.6080 Epoch Acc: 0.00E+00 Epoch Prob: 4.41E-43 Best Probability: 1.13E-27
# Checkpoint saved
# Epoch 185/399 : Tue May  7 07:30:51 2019 - 11h 56m
# ----------
#
# train Loss: 1.2902 Epoch Acc: 0.00E+00 Epoch Prob: 1.26E-06 Best Probability: 1.13E-27
# val Loss: 3.7956 Epoch Acc: 0.00E+00 Epoch Prob: 3.19E-45 Best Probability: 1.13E-27
# Epoch 186/399 : Tue May  7 07:34:41 2019 - 12h 0m
# ----------
#
# train Loss: 1.3020 Epoch Acc: 0.00E+00 Epoch Prob: 8.62E-07 Best Probability: 1.13E-27
# val Loss: 3.7097 Epoch Acc: 0.00E+00 Epoch Prob: 8.36E-42 Best Probability: 1.13E-27
# Epoch 187/399 : Tue May  7 07:38:32 2019 - 12h 4m
# ----------
#
# train Loss: 1.3514 Epoch Acc: 0.00E+00 Epoch Prob: 1.05E-07 Best Probability: 1.13E-27
# val Loss: 3.5716 Epoch Acc: 0.00E+00 Epoch Prob: 1.14E-29 Best Probability: 1.13E-27
# Epoch 188/399 : Tue May  7 07:42:23 2019 - 12h 7m
# ----------
#
# train Loss: 1.3254 Epoch Acc: 0.00E+00 Epoch Prob: 2.27E-06 Best Probability: 1.13E-27
# val Loss: 3.6673 Epoch Acc: 0.00E+00 Epoch Prob: 2.05E-34 Best Probability: 1.13E-27
# Epoch 189/399 : Tue May  7 07:46:14 2019 - 12h 11m
# ----------
#
# train Loss: 1.3338 Epoch Acc: 0.00E+00 Epoch Prob: 2.51E-06 Best Probability: 1.13E-27
# val Loss: 3.5308 Epoch Acc: 0.00E+00 Epoch Prob: 7.21E-40 Best Probability: 1.13E-27
# Checkpoint saved
# Epoch 190/399 : Tue May  7 07:50:05 2019 - 12h 15m
# ----------
#
# train Loss: 1.3382 Epoch Acc: 0.00E+00 Epoch Prob: 1.48E-07 Best Probability: 1.13E-27
# Epoch 351/399 : Tue May  7 18:08:38 2019 - 22h 34m
# ----------
#
# train Loss: 1.2697 Epoch Acc: 0.00E+00 Epoch Prob: 1.46E-06 Best Probability: 2.91E-24
# val Loss: 3.5336 Epoch Acc: 0.00E+00 Epoch Prob: 1.28E-41 Best Probability: 2.91E-24
# Epoch 352/399 : Tue May  7 18:12:29 2019 - 22h 37m
# ----------
#
# train Loss: 1.2214 Epoch Acc: 0.00E+00 Epoch Prob: 2.32E-07 Best Probability: 2.91E-24
# val Loss: 3.8089 Epoch Acc: 0.00E+00 Epoch Prob: 5.79E-33 Best Probability: 2.91E-24
# Epoch 353/399 : Tue May  7 18:16:19 2019 - 22h 41m
# ----------
#
# train Loss: 1.2683 Epoch Acc: 0.00E+00 Epoch Prob: 1.91E-06 Best Probability: 2.91E-24
# val Loss: 3.5765 Epoch Acc: 0.00E+00 Epoch Prob: 7.46E-46 Best Probability: 2.91E-24
# Epoch 354/399 : Tue May  7 18:20:09 2019 - 22h 45m
# ----------
#
# train Loss: 1.2569 Epoch Acc: 0.00E+00 Epoch Prob: 1.34E-07 Best Probability: 2.91E-24
# val Loss: 3.6052 Epoch Acc: 0.00E+00 Epoch Prob: 2.08E-30 Best Probability: 2.91E-24
# Checkpoint saved
# Epoch 355/399 : Tue May  7 18:23:59 2019 - 22h 49m
# ----------
#
# train Loss: 1.3045 Epoch Acc: 0.00E+00 Epoch Prob: 6.05E-06 Best Probability: 2.91E-24
# val Loss: 3.6261 Epoch Acc: 0.00E+00 Epoch Prob: 2.15E-36 Best Probability: 2.91E-24
# Epoch 356/399 : Tue May  7 18:27:49 2019 - 22h 53m
# ----------
#
# train Loss: 1.2890 Epoch Acc: 0.00E+00 Epoch Prob: 5.29E-07 Best Probability: 2.91E-24
# val Loss: 3.6269 Epoch Acc: 0.00E+00 Epoch Prob: 2.58E-43 Best Probability: 2.91E-24
# Epoch 357/399 : Tue May  7 18:31:39 2019 - 22h 57m
# ----------
#
# train Loss: 1.2635 Epoch Acc: 0.00E+00 Epoch Prob: 1.31E-06 Best Probability: 2.91E-24
# val Loss: 3.7073 Epoch Acc: 0.00E+00 Epoch Prob: 2.35E-43 Best Probability: 2.91E-24
# Epoch 358/399 : Tue May  7 18:35:35 2019 - 23h 1m
# ----------
#
# train Loss: 1.2863 Epoch Acc: 0.00E+00 Epoch Prob: 1.05E-06 Best Probability: 2.91E-24
# val Loss: 3.4971 Epoch Acc: 0.00E+00 Epoch Prob: 1.19E-39 Best Probability: 2.91E-24
# Epoch 359/399 : Tue May  7 18:39:33 2019 - 23h 5m
# ----------
#
# train Loss: 1.2568 Epoch Acc: 0.00E+00 Epoch Prob: 4.34E-06 Best Probability: 2.91E-24
# val Loss: 3.5428 Epoch Acc: 0.00E+00 Epoch Prob: 3.25E-39 Best Probability: 2.91E-24
# Checkpoint saved
# Epoch 360/399 : Tue May  7 18:43:24 2019 - 23h 8m
# ----------
#
# train Loss: 1.2326 Epoch Acc: 0.00E+00 Epoch Prob: 1.09E-06 Best Probability: 2.91E-24
# val Loss: 3.5519 Epoch Acc: 0.00E+00 Epoch Prob: 6.23E-41 Best Probability: 2.91E-24
# Epoch 361/399 : Tue May  7 18:47:15 2019 - 23h 12m
# ----------
#
# train Loss: 1.2950 Epoch Acc: 0.00E+00 Epoch Prob: 2.65E-06 Best Probability: 2.91E-24
# val Loss: 3.6173 Epoch Acc: 0.00E+00 Epoch Prob: 8.53E-40 Best Probability: 2.91E-24
# Epoch 362/399 : Tue May  7 18:51:06 2019 - 23h 16m
# ----------
#
# train Loss: 1.2540 Epoch Acc: 0.00E+00 Epoch Prob: 1.53E-06 Best Probability: 2.91E-24
# val Loss: 3.6386 Epoch Acc: 0.00E+00 Epoch Prob: 9.46E-44 Best Probability: 2.91E-24
# Epoch 363/399 : Tue May  7 18:54:57 2019 - 23h 20m
# ----------
#
# train Loss: 1.2417 Epoch Acc: 0.00E+00 Epoch Prob: 2.63E-06 Best Probability: 2.91E-24
# val Loss: 3.6930 Epoch Acc: 0.00E+00 Epoch Prob: 5.26E-40 Best Probability: 2.91E-24
# Epoch 364/399 : Tue May  7 18:58:48 2019 - 23h 24m
# ----------
#
# train Loss: 1.2510 Epoch Acc: 0.00E+00 Epoch Prob: 8.88E-07 Best Probability: 2.91E-24
# val Loss: 3.5654 Epoch Acc: 0.00E+00 Epoch Prob: 1.12E-38 Best Probability: 2.91E-24
# Checkpoint saved
# Epoch 365/399 : Tue May  7 19:02:39 2019 - 23h 28m
# ----------
#
# train Loss: 1.2130 Epoch Acc: 0.00E+00 Epoch Prob: 1.55E-07 Best Probability: 2.91E-24
# val Loss: 3.6238 Epoch Acc: 0.00E+00 Epoch Prob: 5.91E-35 Best Probability: 2.91E-24
# Epoch 366/399 : Tue May  7 19:06:29 2019 - 23h 31m
# ----------
#
# train Loss: 1.2803 Epoch Acc: 0.00E+00 Epoch Prob: 2.05E-07 Best Probability: 2.91E-24
# val Loss: 3.5793 Epoch Acc: 0.00E+00 Epoch Prob: 1.16E-35 Best Probability: 2.91E-24
# Epoch 367/399 : Tue May  7 19:10:20 2019 - 23h 35m
# ----------
#
# train Loss: 1.3109 Epoch Acc: 0.00E+00 Epoch Prob: 2.36E-06 Best Probability: 2.91E-24
# val Loss: 3.5320 Epoch Acc: 0.00E+00 Epoch Prob: 1.61E-36 Best Probability: 2.91E-24
# Epoch 368/399 : Tue May  7 19:14:11 2019 - 23h 39m
# ----------
#
# train Loss: 1.2722 Epoch Acc: 0.00E+00 Epoch Prob: 3.00E-07 Best Probability: 2.91E-24
# val Loss: 3.6299 Epoch Acc: 0.00E+00 Epoch Prob: 5.96E-39 Best Probability: 2.91E-24
# Epoch 369/399 : Tue May  7 19:18:00 2019 - 23h 43m
# ----------
#
# train Loss: 1.2027 Epoch Acc: 0.00E+00 Epoch Prob: 6.57E-07 Best Probability: 2.91E-24
# val Loss: 3.7172 Epoch Acc: 0.00E+00 Epoch Prob: 1.03E-35 Best Probability: 2.91E-24
# Checkpoint saved
# Epoch 370/399 : Tue May  7 19:21:51 2019 - 23h 47m
# ----------
#
# train Loss: 1.2302 Epoch Acc: 0.00E+00 Epoch Prob: 3.03E-07 Best Probability: 2.91E-24
# val Loss: 3.6029 Epoch Acc: 0.00E+00 Epoch Prob: 6.52E-40 Best Probability: 2.91E-24
# Epoch 371/399 : Tue May  7 19:25:41 2019 - 23h 51m
# ----------
#
# train Loss: 1.2836 Epoch Acc: 0.00E+00 Epoch Prob: 1.73E-06 Best Probability: 2.91E-24
# val Loss: 3.5572 Epoch Acc: 0.00E+00 Epoch Prob: 1.27E-35 Best Probability: 2.91E-24
# Epoch 372/399 : Tue May  7 19:29:32 2019 - 23h 55m
# ----------
#
# train Loss: 1.2318 Epoch Acc: 0.00E+00 Epoch Prob: 4.18E-06 Best Probability: 2.91E-24
# val Loss: 3.6222 Epoch Acc: 0.00E+00 Epoch Prob: 1.33E-39 Best Probability: 2.91E-24
# Epoch 373/399 : Tue May  7 19:33:22 2019 - 23h 58m
# ----------
#
# train Loss: 1.2660 Epoch Acc: 0.00E+00 Epoch Prob: 2.35E-07 Best Probability: 2.91E-24
# val Loss: 3.6126 Epoch Acc: 0.00E+00 Epoch Prob: 2.90E-41 Best Probability: 2.91E-24
# Epoch 374/399 : Tue May  7 19:37:14 2019 - 24h 2m
# ----------
#
# train Loss: 1.2716 Epoch Acc: 0.00E+00 Epoch Prob: 5.16E-06 Best Probability: 2.91E-24
# val Loss: 3.5694 Epoch Acc: 0.00E+00 Epoch Prob: 1.04E-36 Best Probability: 2.91E-24
# Checkpoint saved
# Epoch 375/399 : Tue May  7 19:41:05 2019 - 24h 6m
# ----------
#
# train Loss: 1.2180 Epoch Acc: 0.00E+00 Epoch Prob: 1.27E-06 Best Probability: 2.91E-24
# val Loss: 3.5783 Epoch Acc: 0.00E+00 Epoch Prob: 1.06E-41 Best Probability: 2.91E-24
# Epoch 376/399 : Tue May  7 19:44:56 2019 - 24h 10m
# ----------
#
# train Loss: 1.2587 Epoch Acc: 0.00E+00 Epoch Prob: 4.47E-07 Best Probability: 2.91E-24
# val Loss: 3.5535 Epoch Acc: 0.00E+00 Epoch Prob: 7.94E-39 Best Probability: 2.91E-24
# Epoch 377/399 : Tue May  7 19:48:55 2019 - 24h 14m
# ----------
#
# train Loss: 1.2301 Epoch Acc: 0.00E+00 Epoch Prob: 3.85E-06 Best Probability: 2.91E-24
# val Loss: 3.5602 Epoch Acc: 0.00E+00 Epoch Prob: 1.68E-34 Best Probability: 2.91E-24
# Epoch 378/399 : Tue May  7 19:53:31 2019 - 24h 19m
# ----------
#
# train Loss: 1.2791 Epoch Acc: 0.00E+00 Epoch Prob: 2.10E-07 Best Probability: 2.91E-24
# val Loss: 3.7185 Epoch Acc: 0.00E+00 Epoch Prob: 2.01E-33 Best Probability: 2.91E-24
# Epoch 379/399 : Tue May  7 19:57:52 2019 - 24h 23m
# ----------
# train Loss: 1.2701 Epoch Acc: 0.00E+00 Epoch Prob: 3.10E-06 Best Probability: 2.91E-24
# val Loss: 3.8702 Epoch Acc: 0.00E+00 Epoch Prob: 2.38E-29 Best Probability: 2.91E-24
# Checkpoint saved
# Epoch 380/399 : Tue May  7 20:02:11 2019 - 24h 27m
# ----------
#
# train Loss: 1.2179 Epoch Acc: 0.00E+00 Epoch Prob: 4.91E-06 Best Probability: 2.91E-24
# val Loss: 3.6270 Epoch Acc: 0.00E+00 Epoch Prob: 9.79E-40 Best Probability: 2.91E-24
# Epoch 381/399 : Tue May  7 20:06:25 2019 - 24h 31m
# ----------
#
# train Loss: 1.2851 Epoch Acc: 0.00E+00 Epoch Prob: 3.74E-07 Best Probability: 2.91E-24
# val Loss: 3.6208 Epoch Acc: 0.00E+00 Epoch Prob: 4.36E-41 Best Probability: 2.91E-24
# Epoch 382/399 : Tue May  7 20:10:40 2019 - 24h 36m
# ----------
#
# train Loss: 1.2382 Epoch Acc: 0.00E+00 Epoch Prob: 8.66E-08 Best Probability: 2.91E-24
# val Loss: 3.5670 Epoch Acc: 0.00E+00 Epoch Prob: 5.95E-40 Best Probability: 2.91E-24
# Epoch 383/399 : Tue May  7 20:14:50 2019 - 24h 40m
# ----------
#
# train Loss: 1.3275 Epoch Acc: 0.00E+00 Epoch Prob: 2.35E-06 Best Probability: 2.91E-24
# val Loss: 3.4555 Epoch Acc: 0.00E+00 Epoch Prob: 6.92E-40 Best Probability: 2.91E-24
# Epoch 384/399 : Tue May  7 20:18:55 2019 - 24h 44m
# ----------
#
# train Loss: 1.2309 Epoch Acc: 0.00E+00 Epoch Prob: 4.06E-06 Best Probability: 2.91E-24
# val Loss: 3.6724 Epoch Acc: 0.00E+00 Epoch Prob: 1.08E-32 Best Probability: 2.91E-24
# Checkpoint saved
# Epoch 385/399 : Tue May  7 20:22:56 2019 - 24h 48m
# ----------
#
# train Loss: 1.2283 Epoch Acc: 0.00E+00 Epoch Prob: 4.09E-07 Best Probability: 2.91E-24
# val Loss: 3.7574 Epoch Acc: 0.00E+00 Epoch Prob: 7.70E-39 Best Probability: 2.91E-24
# Epoch 386/399 : Tue May  7 20:26:55 2019 - 24h 52m
# ----------
#
# train Loss: 1.2109 Epoch Acc: 4.00E-05 Epoch Prob: 5.69E-06 Best Probability: 2.91E-24
# val Loss: 3.6608 Epoch Acc: 0.00E+00 Epoch Prob: 3.27E-40 Best Probability: 2.91E-24
# Epoch 387/399 : Tue May  7 20:30:53 2019 - 24h 56m
# ----------
#
# train Loss: 1.2781 Epoch Acc: 0.00E+00 Epoch Prob: 4.08E-07 Best Probability: 2.91E-24
# val Loss: 3.7175 Epoch Acc: 0.00E+00 Epoch Prob: 5.61E-43 Best Probability: 2.91E-24
# Epoch 388/399 : Tue May  7 20:34:55 2019 - 25h 0m
# ----------
#
# train Loss: 1.2904 Epoch Acc: 0.00E+00 Epoch Prob: 3.43E-07 Best Probability: 2.91E-24
# val Loss: 3.5603 Epoch Acc: 0.00E+00 Epoch Prob: 1.94E-42 Best Probability: 2.91E-24
# Epoch 389/399 : Tue May  7 20:38:57 2019 - 25h 4m
# ----------
#
# train Loss: 1.2426 Epoch Acc: 0.00E+00 Epoch Prob: 5.30E-06 Best Probability: 2.91E-24
# val Loss: 3.6341 Epoch Acc: 0.00E+00 Epoch Prob: 6.09E-33 Best Probability: 2.91E-24
# Checkpoint saved
# Epoch 390/399 : Tue May  7 20:42:54 2019 - 25h 8m
# ----------
#
# train Loss: 1.2245 Epoch Acc: 0.00E+00 Epoch Prob: 2.05E-06 Best Probability: 2.91E-24
# val Loss: 3.5949 Epoch Acc: 0.00E+00 Epoch Prob: 1.28E-32 Best Probability: 2.91E-24
# Epoch 391/399 : Tue May  7 20:46:51 2019 - 25h 12m
# ----------
#
# train Loss: 1.2692 Epoch Acc: 0.00E+00 Epoch Prob: 1.44E-07 Best Probability: 2.91E-24
# val Loss: 3.7051 Epoch Acc: 0.00E+00 Epoch Prob: 4.55E-31 Best Probability: 2.91E-24
# Epoch 392/399 : Tue May  7 20:50:54 2019 - 25h 16m
# ----------
#
# train Loss: 1.2314 Epoch Acc: 0.00E+00 Epoch Prob: 1.35E-06 Best Probability: 2.91E-24
# val Loss: 3.6087 Epoch Acc: 0.00E+00 Epoch Prob: 3.26E-35 Best Probability: 2.91E-24
# Epoch 393/399 : Tue May  7 20:54:57 2019 - 25h 20m
# ----------
#
# train Loss: 1.2402 Epoch Acc: 0.00E+00 Epoch Prob: 2.72E-07 Best Probability: 2.91E-24
# val Loss: 3.8774 Epoch Acc: 0.00E+00 Epoch Prob: 7.39E-41 Best Probability: 2.91E-24
# Epoch 394/399 : Tue May  7 20:58:56 2019 - 25h 24m
# ----------
#
# train Loss: 1.2847 Epoch Acc: 0.00E+00 Epoch Prob: 1.37E-06 Best Probability: 2.91E-24
# val Loss: 3.5669 Epoch Acc: 0.00E+00 Epoch Prob: 5.90E-39 Best Probability: 2.91E-24
# Checkpoint saved
# Epoch 395/399 : Tue May  7 21:02:57 2019 - 25h 28m
# ----------
#
# train Loss: 1.2501 Epoch Acc: 0.00E+00 Epoch Prob: 8.66E-06 Best Probability: 2.91E-24
# val Loss: 3.5825 Epoch Acc: 0.00E+00 Epoch Prob: 1.87E-49 Best Probability: 2.91E-24
# Epoch 396/399 : Tue May  7 21:07:03 2019 - 25h 32m
# ----------
#
# train Loss: 1.2145 Epoch Acc: 0.00E+00 Epoch Prob: 4.27E-06 Best Probability: 2.91E-24
# val Loss: 3.7497 Epoch Acc: 0.00E+00 Epoch Prob: 2.10E-34 Best Probability: 2.91E-24
# Epoch 397/399 : Tue May  7 21:11:10 2019 - 25h 36m
# ----------
#
# train Loss: 1.2912 Epoch Acc: 0.00E+00 Epoch Prob: 5.49E-07 Best Probability: 2.91E-24
# val Loss: 3.5224 Epoch Acc: 0.00E+00 Epoch Prob: 4.35E-32 Best Probability: 2.91E-24
# Epoch 398/399 : Tue May  7 21:15:17 2019 - 25h 40m
# ----------
#
# train Loss: 1.2245 Epoch Acc: 0.00E+00 Epoch Prob: 1.58E-07 Best Probability: 2.91E-24
# val Loss: 3.6334 Epoch Acc: 0.00E+00 Epoch Prob: 2.69E-31 Best Probability: 2.91E-24
# Epoch 399/399 : Tue May  7 21:19:24 2019 - 25h 44m
# ----------
#
# train Loss: 1.1940 Epoch Acc: 0.00E+00 Epoch Prob: 5.51E-07 Best Probability: 2.91E-24
# val Loss: 3.7219 Epoch Acc: 0.00E+00 Epoch Prob: 1.89E-43 Best Probability: 2.91E-24
# Checkpoint saved
# Training complete in 25hr 48m 57s

# %%
out = model_ft(test_batch)
out = out.squeeze(3)
out2 = out.permute(0,2,1)
outText = []
loader = DataLoader(filePath = FilePaths.fnTrain, batchSize = Model.batchSize, imgSize = Model.imgSize, maxTextLen = Model.maxTextLen)
charList = loader.charList
for i in range (out2.shape[0]):
    softmaxOut = torch.nn.functional.softmax(out2[i], dim = 1).cuda()
    softmaxOut = softmaxOut.cpu().detach().numpy()
    print (softmaxOut[0][0])
    outText.append(BestPath.ctcBestPath(softmaxOut, charList))
print (outText)
print (test_labels)
# Out:
# 1.0
# 1.0
# 1.0
# 1.0
# 0.9999999
# 1.0
# 1.0
# 1.0
# 0.99988544
# 0.99990237
# 1.0
# 0.9999596
# 0.9951139
# 1.0
# 1.0
# 0.9999596
# 0.9994369
# 0.94125503
# 0.9999747
# 0.9999664
# 0.9999747
# 1.0
# 0.9999838
# 0.9999734
# 0.99997485
# 1.0
# 0.99997306
# 1.0
# 1.0
# 0.9834812
# 0.99998367
# 0.9998103
# 1.0
# 0.99986017
# 0.9999713
# 0.99997175
# 0.9999732
# 1.0
# 0.98067427
# 0.99993765
# 1.0
# 0.9996618
# 0.99883
# 0.99997187
# 0.9998204
# 0.9456496
# 1.0
# 0.9664101
# 0.99999464
# 1.0
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['bit', ',', 'Di', ',', '"', 'he', 'told', 'her', '.', '"', 'But', 'I', 'want', 'it', '!', '"', 'she', 'protested', '.', '"', 'It', "'s", 'my', 'ring', '.', '"', '"', 'You', 'just', 'gave', 'it', 'back', 'to', 'me', '.', '"', '"', 'I', "didn't", '!', 'I', 'was', 'joking', '.', 'You', 'know', 'I', 'was', 'joking', ',']

# %%
out = model_ft(test_batch)
out = out.squeeze(3)
out2 = out.permute(0,2,1)
#rnn = rnn.squeeze(3)
print(rnn.size())
print (test_batch.shape[0])
# Out:
# torch.Size([50, 512])
# torch.Size([50, 512])
# 50

# %%
cv2.imshow('original vs sharpened image', test_batch[2])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
for i in range (rnn.shape[0]):
    print(rnn[i][4])
# Out:
# tensor(0.0109, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0113, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0113, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0128, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0107, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0111, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0111, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0109, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0120, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0109, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0154, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0120, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(-0.0216, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0157, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0121, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0120, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0112, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(-0.0577, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0120, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0108, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0121, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0140, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0108, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0114, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0120, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0115, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0107, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0106, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0103, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0019, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0115, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(-0.0167, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0113, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0012, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0111, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0113, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0115, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0158, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0028, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0110, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0154, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0002, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0078, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0117, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0105, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(-0.0282, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0146, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(-0.0100, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0044, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(0.0155, device='cuda:0', grad_fn=<SelectBackward>)
